# %%
import numpy as np # linear algebra 
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
# stats models: regression fitting via formulas
import statsmodels.formula.api as smf
# stats models: regression fitting via matrices of regression design
import statsmodels.api as sm
wg=pd.read_csv('https://raw.githubusercontent.com/artamonoff/Econometrica/master/python-notebooks/data-csv/sleep75.csv')
wg
# Out:
#      age  black  case  clerical  construc  educ  earns74  gdhlth  inlf  leis1  \
# 0     32      0     1  0.000000  0.000000    12        0       0     1   3529
# 1     31      0     2  0.000000  0.000000    14     9500       1     1   2140
# 2     44      0     3  0.000000  0.000000    17    42500       1     1   4595
# 3     30      0     4  0.000000  0.000000    12    42500       1     1   3211
# 4     64      0     5  0.000000  0.000000    14     2500       1     1   4052
# ..   ...    ...   ...       ...       ...   ...      ...     ...   ...    ...
# 701   45      0   702  0.182331  0.030075    12     5500       1     0   5069
# 702   34      0   703  0.182331  0.030075    10     2500       0     0   5885
# 703   37      0   704  0.182331  0.030075    12     3500       1     0   4719
# 704   54      0   705  0.182331  0.030075    17    32500       1     0   5149
# 705   30      0   706  0.182331  0.030075    16     6750       1     0   4747
#
# ...

# %%
#1.2
sleep_eq1 = smf.ols(formula='sleep~totwrk+male+smsa+age+south+yngkid+marr+union', data=wg).fit()
sleep_eq1.params.round(2)
# Out:
# Intercept    3446.83
# totwrk         -0.17
# male           87.11
# smsa          -54.19
# age             2.71
# south         102.27
# yngkid        -13.05
# marr           31.36
# union          11.87
# dtype: float64

# %% [markdown]
# $$
# sleep=3446.83-0.17*totwrk+87.11*male-54.19*smsa+2.71*age+102.27*south-13.05*yngkid+31.36*marr+11.87*union
# $$

# %% [markdown]
# ## Интерператция:
# 1. При увеличении рабочего времени в неделю количество сна уменьшается на 0.17 минуты
# 2. Мужчины спят на 87.11 минуты в неделю больше женщин

# %%
# 1.3
sleep_eq1 = smf.ols(formula='sleep~np.log(hrwage)+smsa+totwrk+male+age+marr+south+yngkid', data=wg).fit()
sleep_eq1.params.round(2)
# Out:
# Intercept         3440.19
# np.log(hrwage)      -1.39
# smsa               -36.96
# totwrk              -0.16
# male                36.87
# age                  2.37
# marr                53.34
# south               76.27
# yngkid              47.92
# dtype: float64

# %% [markdown]
# $$
# sleep=3440.19-1.39log(hrwage)-36.96smsa-0.16totwrk+36.87male+2.37age+53.34marr+76.27south+47.92yngkid
# $$

# %% [markdown]
# # Интерпретация
# 1. При увеличении почасовой оплаты на 1% процент количество сна уменьшается на 0.0139 минты
# 2. Количество сна в неделю уменьшается на 36.96 минут, если человек живет в мегаполисе

# %%
#2.1 
prrp=pd.read_csv('https://raw.githubusercontent.com/artamonoff/Econometrica/master/python-notebooks/data-csv/wage2.csv')
prrp
# Out:
#      wage  hours   IQ  KWW  educ  exper  tenure  age  married  black  south  \
# 0     769     40   93   35    12     11       2   31        1      0      0
# 1     808     50  119   41    18     11      16   37        1      0      0
# 2     825     40  108   46    14     11       9   33        1      0      0
# 3     650     40   96   32    12     13       7   32        1      0      0
# 4     562     40   74   27    11     14       5   34        1      0      0
# ..    ...    ...  ...  ...   ...    ...     ...  ...      ...    ...    ...
# 930   520     40   79   28    16      6       1   30        1      1      1
# 931  1202     40  102   32    13     10       3   31        1      0      1
# 932   538     45   77   22    12     12      10   28        1      1      1
# 933   873     44  109   25    12     12      12   28        1      0      1
# 934  1000     40  107   32    12     17      18   35        1      0      1
#
#      urban  sibs  brthord  meduc  feduc     lwage
# ...

# %%
wageeq= smf.ols(formula='np.log(wage)~age+IQ', data=prrp).fit()
wageeq.params.round(3)
# Out:
# Intercept    5.077
# age          0.024
# IQ           0.009
# dtype: float64

# %% [markdown]
# $$
# log(wage)=5.077+0.024age+0.009IQ
# $$

# %% [markdown]
# ### Интерпретация
# 1. При увеличкении возраста на 1 год зарплата увеличивается на 2.4%
# 2. При увеличении IQ на 1 зарплата увеличивается на 0.9%

# %%
#3.1
lab=pd.read_csv('https://raw.githubusercontent.com/artamonoff/Econometrica/master/python-notebooks/data-csv/Labour.csv')
lab
# Out:
#        capital  labour     output       wage
# 0     2.606563     184   9.250759  43.080307
# 1     1.323237      91   3.664310  27.780016
# 2    22.093692     426  28.781516  44.467748
# 3    10.737851      72   4.124642  39.734710
# 4     1.161365      46   2.890150  34.650709
# ..         ...     ...        ...        ...
# 564   2.625403      20   1.424376  33.477545
# 565   1.276386      61   2.109048  26.300732
# 566   1.953869     117   6.241870  41.153979
# 567   1.318527      46   7.902237  66.720139
# 568   2.832391     161   6.804085  36.618435
#
# [569 rows x 4 columns]

# %%
#3.1
lab_eq1 = smf.ols(formula='np.log(output)~np.log(capital)+np.log(labour)', data=lab).fit()
lab_eq1.params.round(3)
# Out:
# Intercept         -1.711
# np.log(capital)    0.208
# np.log(labour)     0.715
# dtype: float64

# %% [markdown]
# $$
# log(output)=-1.711+0.208log(capital)+0.715log(labour)
# $$

# %% [markdown]
# ### Интерпретация
# 1. При увеличении капитала на 1% выпуск увеличивается на 0.2%
# 2. При увеличении затрачиваемого труда на 1% выпуск увеличивается на 0.7%

# %%
#3.2
lab_eq2 = smf.ols(formula='np.log(output)~np.log(capital)+np.log(labour)+np.log(wage)', data=lab).fit()
lab_eq2.params.round(3)
# Out:
# Intercept         -5.007
# np.log(capital)    0.149
# np.log(labour)     0.720
# np.log(wage)       0.921
# dtype: float64

# %% [markdown]
# log(output)=-5.007+0.149log(capital)+0.72log(labour)+0.921log(wage)

# %% [markdown]
# ### Интерпретация
# 1. При увеличении каптала на 1% выпуск увеличивается на 0.149%
# 2. При увеличении затрачиваемого труда на 1% выпуск увеличивается на 0.921%

# %%
el=pd.read_csv('https://raw.githubusercontent.com/artamonoff/Econometrica/master/python-notebooks/data-csv/Electricity.csv')

el
# Out:
#         cost        q        pl      sl      pk      sk      pf      sf
# 0     0.2130      8.0   6869.47  0.3291  64.945  0.4197  18.000  0.2512
# 1     3.0427    869.0   8372.96  0.1030  68.227  0.2913  21.067  0.6057
# 2     9.4059   1412.0   7960.90  0.0891  40.692  0.1567  41.530  0.7542
# 3     0.7606     65.0   8971.89  0.2802  41.243  0.1282  28.539  0.5916
# 4     2.2587    295.0   8218.40  0.1772  71.940  0.1623  39.200  0.6606
# ..       ...      ...       ...     ...     ...     ...     ...     ...
# 153   6.8293    946.6  10642.16  0.0883  43.600  0.1914  51.463  0.7203
# 154   3.7605    377.0   7432.24  0.2117  74.120  0.2274  33.436  0.5609
# 155   3.9822    391.0   5826.04  0.1926  78.288  0.0924  44.633  0.7151
# 156  30.1880   5317.0   9586.63  0.0845  78.008  0.2009  41.840  0.7147
# 157  67.8562  15220.0   6986.09  0.1451  74.025  0.2596  25.662  0.5945
#
# [158 rows x 8 columns]

# %%
#4.1
el_eq1 = smf.ols(formula='np.log(cost)~np.log(q)', data=el).fit()
el_eq1.params.round(3)
# Out:
# Intercept   -3.841
# np.log(q)    0.836
# dtype: float64

# %% [markdown]
# $$
# log(cost)=-3.841+0.836log(q)
# $$

# %% [markdown]
# ### Интерпретация
# 1. При увеличении общего выпуска элетроэнергии за год на 1% общие издержки за год увеличиваются на 0.836%

# %%
#4.2
el_eq2 = smf.ols(formula='np.log(cost)~np.log(q)+np.log(pl)+np.log(pf)+np.log(pk)', data=el).fit()
el_eq2.params.round(3)
# Out:
# Intercept    -7.472
# np.log(q)     0.838
# np.log(pl)    0.044
# np.log(pf)    0.713
# np.log(pk)    0.188
# dtype: float64

# %% [markdown]
# $$
# log(cost)=-7.472+0.838log(q)+0.044log(pl)+0.713log(pf)+0.188log(pk)
# $$

# %% [markdown]
# ### Интерпретация
# 1. При увеличении общего выпуска элетроэнергии за год на 1% общие издержки за год увеличиваются на 0.838%
